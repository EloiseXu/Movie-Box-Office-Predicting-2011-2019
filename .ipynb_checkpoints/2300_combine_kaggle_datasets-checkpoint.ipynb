# %% [markdown]
# # Combining the google and apple datasets
#
# __Purpose__
#
# This notebook is going to bring together the google and apple datasets.

# %%
from os.path import exists, isfile
import random
import time

import re
import math

import pandas as pd
import numpy as np
import math
from loguru import logger

# %%
save_path = '../../datasets/2300_combine_kaggle_datasets.csv'

# %%
if not exists("../../datasets/2200_clean_apple.csv"):
    print ("Missing dataset file")
    
df_apple=pd.read_csv("../../datasets/2200_clean_apple.csv")
df_apple.head()
# Out:
#     apple_id                                        apple_title  apple_size  \
# 0  281656475                                    PAC-MAN Premium   96.119141
# 1  281796108                          Evernote - stay organized  151.232422
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   95.867188
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...  122.558594
# 4  282935706                                              Bible   88.476562
#
#    apple_price  apple_reviews  apple_rating apple_pegi        apple_genre  \
# 0         3.99          21292           4.0   Everyone              Games
# 1         0.00         161065           4.0   Everyone           Business
# 2         0.00         188583           3.5   Everyone             Others
# 3         0.00         262241           4.0       Teen          Lifestyle
# 4         0.00         985920           4.5   Everyone  Books & Reference
#
#    normed_apple_rating  z_score_apple  log_apple_reviews
# 0                  0.8      -0.083987           4.328216
# 1                  0.8      -0.083987           5.207001
# 2                  0.7      -0.806018           5.275503
# 3                  0.8      -0.083987           5.418701
# 4                  0.9       0.638043           5.993842

# %%
if not exists("../../datasets/2100_clean_google.csv"):
    print ("Missing dataset file")
    
df_google=pd.read_csv("../../datasets/2100_clean_google.csv")
df_google.head()
# Out:
#                                         google_title google_genre  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook    Utilities
# 1                                Coloring book moana    Utilities
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...    Utilities
# 3                              Sketch - Draw & Paint    Utilities
# 4              Pixel Draw - Number Art Coloring Book    Utilities
#
#    google_rating  google_reviews  google_size  google_price google_pegi  \
# 0            4.1             159         19.0           0.0    Everyone
# 1            3.9             967         14.0           0.0    Everyone
# 2            4.7           87510          8.7           0.0    Everyone
# 3            4.5          215644         25.0           0.0        Teen
# 4            4.3             967          2.8           0.0    Everyone
#
#    log_google_reviews  normed_google_rating  z_score_google
# 0            2.201397                  0.82       -0.143135
# 1            2.985426                  0.78       -0.537987
# 2            4.942058                  0.94        1.041422
# 3            5.333737                  0.90        0.646570
# 4            2.985426                  0.86        0.251718

# %% [markdown]
# # Title to title mappings
#
# The same apps can have different titles when they are released in different platforms. This happens when the title of each app is in the format like "A - B" or "A : B". However, some apps have titles like "A - B" or "A : B" but they are different. For example, different games in a series can have titles like "A - B", "A - C", and "A - D" but they cannot be considered as the same app.
#
# A possible solution to this problem is, first take "A" out of "A - B" or "A : B" and save it as the key to combine two datasets. If such a key is unique in the new dataset, we simply consider it as a perfect match. However, when such a key is not unique, we only consider those matches with the same google title and apple title as the correct match.

# %%
logger.info('Title to title mappings')

def clean_title(x):
    x = str(x)
    pos1 = x.find('-')
    pos2 = x.find('–')
    pos3 = x.find(':')
    pos4 = x.find('(')
    if pos1 != -1:
        x = x[:pos1].strip()
    if pos2 != -1:
        x = x[:pos2].strip()
    if pos3 != -1:
        x = x[:pos3].strip()
    if pos4 != -1:
        x = x[:pos4].strip()
    r1 = '[’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~]+'
    x = re.sub(r1, '', x)
    x = x.strip()
    return x
# Out:
# 2019-05-10 21:42:13.047 | INFO     | __main__:<module>:1 - Title to title mappings

# %%
df_google['trim_title'] = df_google['google_title'].apply(clean_title)
df_apple['trim_title'] = df_apple['apple_title'].apply(clean_title)

# %%
combine_apps = df_apple.set_index('trim_title').join(
    df_google.set_index('trim_title'), how='inner').reset_index()
combine_apps.shape
# Out:
# (781, 22)

# %%
same_title = combine_apps[(combine_apps.duplicated('trim_title') == True) & (combine_apps['google_title'] == combine_apps['apple_title'])]
same_trim = combine_apps[combine_apps.duplicated('trim_title') == False]
combine_apps = same_title.append(same_trim)
combine_apps.sample(10)
# Out:
#                 trim_title    apple_id  \
# 447            Onefootball   382002079
# 95                CBS News   334256223
# 615   Talking Tom Gold Run  1089336971
# 3                     2048   840919914
# 275            Geocaching®   329541503
# 495          Pineapple Pen  1159035153
# 180             DraftKings   710535379
# 341            InstaBeauty   599534650
# 361            Last Empire  1040083067
# 523  Retro City Rampage DX  1088540036
#
#                                            apple_title  apple_size  \
# 447            Onefootball - Soccer Scores & Live News  108.541992
# 95            CBS News - Watch Free Live Breaking News   74.431641
# 615   Talking Tom Gold Run: Fun & Endless Running Game  193.159180
# 3                                                 2048   14.816406
# 275                                        Geocaching®  103.155273
# 495                                      Pineapple Pen   93.414062
# 180  DraftKings - Daily Fantasy Golf, Baseball, & More  138.111328
# 341  InstaBeauty -Camera&Photo Editor&Pic Collage M...   84.768555
# 361          Last Empire – War Z: Zombie Strategy Game  142.132812
# 523                              Retro City Rampage DX   14.888672
#
#      apple_price  apple_reviews  apple_rating  apple_pegi        apple_genre  \
# 447         0.00           3194           4.5        Teen   Health & Fitness
# 95          0.00          11691           3.5        Teen               News
# 615         0.00          18733           4.5    Everyone              Games
# 3           0.00         157882           4.5    Everyone              Games
# 275         0.00          12811           3.5    Everyone    Auto & Vehicles
# 495         0.00           6430           4.5    Everyone              Games
# 180         0.00          20251           4.5  Mature 17+   Health & Fitness
# 341         0.00           4818           4.5    Everyone  Social Networking
# 361         0.00           3323           4.0        Teen              Games
# 523         4.99             68           4.5        Teen              Games
#
#      normed_apple_rating  ...                       google_title  \
# 447                  0.9  ...        Onefootball - Soccer Scores
# 95                   0.7  ...                           CBS News
# 615                  0.9  ...               Talking Tom Gold Run
# 3                    0.9  ...                           2048(AI)
# 275                  0.7  ...                        Geocaching®
# 495                  0.9  ...                      Pineapple Pen
# 180                  0.9  ...  DraftKings - Daily Fantasy Sports
# 341                  0.9  ...     InstaBeauty -Makeup Selfie Cam
# 361                  0.8  ...      Last Empire - War Z: Strategy
# 523                  0.9  ...              Retro City Rampage DX
#
#           google_genre google_rating google_reviews  google_size  \
# 447   Health & Fitness           4.7         911995         20.0
# 95                News           4.3          23641         23.0
# 615              Games           4.6        2698348         78.0
# 3               Others           4.3             20          3.5
# 275   Health & Fitness           4.1          62616          NaN
# 495              Games           4.3         157264         65.0
# 180   Health & Fitness           4.5          50017         41.0
# 341  Books & Reference           4.3         654419          NaN
# 361             Others           4.2         853495         78.0
# 523              Games           4.7            416         16.0
#
#      google_price   google_pegi  log_google_reviews normed_google_rating  \
# 447          0.00      Everyone            5.959992                 0.94
# 95           0.00  Everyone 10+            4.373666                 0.86
# 615          0.00      Everyone            6.431098                 0.92
# 3            0.00      Everyone            1.301030                 0.86
# 275          0.00          Teen            4.796685                 0.82
# 495          0.00      Everyone            5.196629                 0.86
# 180          0.00    Mature 17+            4.699118                 0.90
# 341          0.00      Everyone            5.815856                 0.86
# 361          0.00          Teen            5.931201                 0.84
# 523          2.99          Teen            2.619093                 0.94
#
#      z_score_google
# 447        1.041422
# 95         0.251718
# 615        0.843996
# 3          0.251718
# 275       -0.143135
# 495        0.251718
# 180        0.646570
# 341        0.251718
# 361        0.054292
# 523        1.041422
#
# [10 rows x 22 columns]

# %% [markdown]
# # Difference between ratings
#
# The difference of each app's two ratings is calculated here.

# %%
logger.info('Difference between ratings')

combine_apps['z_score_google_sub_apple'] = combine_apps['z_score_google'] - combine_apps['z_score_apple']
combine_apps.sample(5)
# Out:
# 2019-05-10 21:42:13.251 | INFO     | __main__:<module>:1 - Difference between ratings
#                trim_title   apple_id                    apple_title  \
# 162               Discord  985746746      Discord - Chat for Gamers
# 612  THE KING OF FIGHTERS  507937883    THE KING OF FIGHTERS-i 2012
# 202                Edmodo  378352300                         Edmodo
# 301      Grand Theft Auto  763692274  Grand Theft Auto: San Andreas
# 478          Peggle Blast  853834250                   Peggle Blast
#
#       apple_size  apple_price  apple_reviews  apple_rating    apple_pegi  \
# 162    25.644531         0.00           9152           4.5      Everyone
# 612  1140.796875         2.99            228           4.5          Teen
# 202   122.012695         0.00           7197           3.5      Everyone
# 301  1964.965820         6.99          32533           4.0    Mature 17+
# 478   433.679688         0.00          11528           4.0  Everyone 10+
#
#            apple_genre  normed_apple_rating  ...       google_genre  \
# 162  Social Networking                  0.9  ...  Social Networking
# 612              Games                  0.9  ...              Games
# 202          Education                  0.7  ...          Education
# 301              Games                  0.8  ...              Games
# 478              Games                  0.8  ...              Games
#
#      google_rating google_reviews google_size  google_price  google_pegi  \
# 162            4.5         305347        39.0          0.00         Teen
# 612            4.4         406511        21.0          0.00         Teen
# 202            4.1         200058        18.0          0.00     Everyone
# 301            4.4         348962        26.0          6.99   Mature 17+
# 478            4.1         166251        19.0          0.00     Everyone
#
#      log_google_reviews  normed_google_rating z_score_google  \
# 162            5.484794                  0.90       0.646570
# 612            5.609072                  0.88       0.449144
# 202            5.301156                  0.82      -0.143135
# 301            5.542778                  0.88       0.449144
# 478            5.220764                  0.82      -0.143135
#
#      z_score_google_sub_apple
# 162                  0.008527
# 612                 -0.188899
# 202                  0.662884
# 301                  0.533131
# 478                 -0.059147
#
# [5 rows x 23 columns]

# %%
combine_apps['norm_google_sub_apple'] = combine_apps['normed_google_rating'] - combine_apps['normed_apple_rating']
combine_apps.sample(5)
# Out:
#                      trim_title    apple_id                     apple_title  \
# 514                        RISK  1051334048         RISK: Global Domination
# 227             FINAL FANTASY V   609577016                 FINAL FANTASY V
# 16                  AccuWeather   300048137  AccuWeather - Weather for Life
# 149                DB Navigator   343555245                    DB Navigator
# 503  Please Dont Touch Anything  1002503055    Please, Don't Touch Anything
#
#      apple_size  apple_price  apple_reviews  apple_rating    apple_pegi  \
# 514  211.883789         0.00           5217           4.0  Everyone 10+
# 227  159.292969        14.99           1808           4.5  Everyone 10+
# 16   173.512695         0.00         144214           3.5      Everyone
# 149   80.863281         0.00            512           3.5      Everyone
# 503   54.363281         4.99            379           4.0  Everyone 10+
#
#          apple_genre  normed_apple_rating  ...  google_rating  google_reviews  \
# 514            Games                  0.8  ...            4.0           68559
# 227            Games                  0.9  ...            4.5           15924
# 16            Others                  0.7  ...            4.4         2053404
# 149  Auto & Vehicles                  0.7  ...            4.0          119685
# 503            Games                  0.8  ...            4.4            1771
#
#     google_size google_price  google_pegi  log_google_reviews  \
# 514        75.0         0.00     Everyone            4.836064
# 227         4.2         7.99         Teen            4.202052
# 16          NaN         0.00     Everyone            6.312474
# 149        20.0         0.00     Everyone            5.078040
# 503        46.0         4.99         Teen            3.248219
#
#      normed_google_rating  z_score_google z_score_google_sub_apple  \
# 514                  0.80       -0.340561                -0.256573
# 227                  0.90        0.646570                 0.008527
# 16                   0.88        0.449144                 1.255162
# 149                  0.80       -0.340561                 0.465458
# 503                  0.88        0.449144                 0.533131
#
#      norm_google_sub_apple
# 514                   0.00
# 227                   0.00
# 16                    0.18
# 149                   0.10
# 503                   0.08
#
# [5 rows x 24 columns]

# %% [markdown]
# # New columns
#
# We only keep the common features for the new dataset.

# %%
logger.info('New columns')

use_cols = [
    'apple_id', 'trim_title', 'apple_title', 'apple_genre', 'apple_rating',
       'apple_reviews', 'apple_size', 'apple_pegi',
       'normed_apple_rating', 'google_title', 'google_rating',
       'google_reviews', 'google_size', 'google_price', 'apple_price',
       'normed_google_rating', 'log_google_reviews', 'log_apple_reviews',
    'z_score_google', 'z_score_apple', 'z_score_google_sub_apple', 'norm_google_sub_apple'
]

df = combine_apps[use_cols].copy()
df.head()
# Out:
# 2019-05-10 21:42:13.351 | INFO     | __main__:<module>:1 - New columns
#        apple_id        trim_title                    apple_title apple_genre  \
# 107   898968647     Call of Duty®          Call of Duty®: Heroes       Games
# 170  1147297267       Dont Starve      Don't Starve: Shipwrecked       Games
# 223   352670055                 F            F-Sim Space Shuttle       Games
# 301   763692274  Grand Theft Auto  Grand Theft Auto: San Andreas       Games
# 355   771989093     LEGO® Friends                  LEGO® Friends       Games
#
#      apple_rating  apple_reviews   apple_size    apple_pegi  \
# 107           4.5         179416   201.075195          Teen
# 170           3.5            495   604.341797  Everyone 10+
# 223           4.5           6403    72.855469      Everyone
# 301           4.0          32533  1964.965820    Mature 17+
# 355           4.0            400   730.941406      Everyone
#
#      normed_apple_rating                   google_title  ...  google_size  \
# 107                  0.9          Call of Duty®: Heroes  ...         57.0
# 170                  0.7      Don't Starve: Shipwrecked  ...          4.9
# 223                  0.9            F-Sim Space Shuttle  ...          NaN
# 301                  0.8  Grand Theft Auto: San Andreas  ...         26.0
# 355                  0.8                  LEGO® Friends  ...          6.9
#
#      google_price  apple_price  normed_google_rating  log_google_reviews  \
# 107          0.00         0.00                  0.88            6.205244
# 170          4.99         4.99                  0.82            3.166726
# 223          4.99         4.99                  0.88            3.734560
# 301          6.99         6.99                  0.88            5.542778
# 355          4.99         4.99                  0.88            2.931458
#
#      log_apple_reviews  z_score_google  z_score_apple  \
# 107           5.253861        0.449144       0.638043
# 170           2.694605       -0.143135      -0.806018
# 223           3.806384        0.449144       0.638043
# 301           4.512324        0.449144      -0.083987
# 355           2.602060        0.449144      -0.083987
#
#      z_score_google_sub_apple  norm_google_sub_apple
# 107                 -0.188899                  -0.02
# 170                  0.662884                   0.12
# 223                 -0.188899                  -0.02
# 301                  0.533131                   0.08
# 355                  0.533131                   0.08
#
# [5 rows x 22 columns]

# %% [markdown]
# Rename the columns

# %%
df.columns = ['apple_id','trim_title', 'apple_title', 'genre', 'apple_rating',
       'apple_reviews', 'apple_size', 'pegi',
       'normed_apple_rating', 'google_title', 'google_rating',
       'google_reviews', 'google_size', 'google_price', 'apple_price', 
       'normed_google_rating', 'log_google_reviews', 'log_apple_reviews',
    'z_score_google_rating', 'z_score_apple_rating', 'z_score_google_sub_apple','norm_google_sub_apple']
df.shape
# Out:
# (604, 22)

# %% [markdown]
# # Revenues
#
# Each app's price is multiplied by the number of its reviews to estimate its revenue. To evaluate how well an app is received, we will use the new feature "revenue".

# %%
logger.info('Revenues')

df['google_revenue'] = df['google_reviews'] * df['google_price']
df['apple_revenue'] = df['apple_reviews'] * df['apple_price']

df.loc[df['google_revenue']>0,'log_google_revenue'] = df[df['google_revenue']>0]['google_revenue'].apply(lambda x: math.log(x, 10))
df.loc[df['apple_revenue']>0,'log_apple_revenue'] = df[df['apple_revenue']>0]['apple_revenue'].apply(lambda x: math.log(x, 10))
# Out:
# 2019-05-10 21:42:13.417 | INFO     | __main__:<module>:1 - Revenues

# %% [markdown]
# # Save final dataset

# %%
df.to_csv(save_path, index=False)
df.shape
# Out:
# (604, 26)
